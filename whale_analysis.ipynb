# %% [markdown]
#  #  A Whale off the Port(folio)
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500.

# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
# 1. whale_returns.csv
# 2. algo_returns.csv
# 3. sp500_history.csv

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns_csv = Path("Resources/whale_returns.csv")
whale_returns = pd.read_csv(whale_returns_csv, index_col = 'Date', infer_datetime_format = True, parse_dates = True)
whale_returns.head(5)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns.dropna(inplace=True)
whale_returns.head(5)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns_csv = Path("Resources/algo_returns.csv")
algo_returns = pd.read_csv(algo_returns_csv, index_col ='Date', infer_datetime_format = True, parse_dates = True)
algo_returns.head(5)
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns.dropna()
algo_returns.sample(5)
# Out:
#               Algo 1    Algo 2
# Date
# 2019-03-28  0.009932  0.005775
# 2014-08-27  0.000843  0.000053
# 2019-01-10  0.003087  0.003366
# 2017-04-12  0.001635 -0.007078
# 2015-11-06 -0.011657  0.003996

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P500 Historic Closing Prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices, sorting index
sp500_history_csv = Path("Resources/sp500_history.csv")
sp500_history = pd.read_csv(sp500_history_csv, index_col = 'Date', infer_datetime_format = True, parse_dates = True)
sp500_history.head(5)
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Check Data Types
sp500_history.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_history['Close'] = sp500_history['Close'].str.replace('$','')

# %%
# Calculate Daily Returns
sp500_daily_returns = sp500_history.astype(float).pct_change()
sp500_daily_returns.sort_index()
sp500_daily_returns.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
# Drop nulls
sp500_daily_returns.dropna()
sp500_daily_returns.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
# Rename Column
sp500_daily_returns =sp500_daily_returns.rename(columns ={"Close": "S&P 500",})
sp500_daily_returns.head()
# Out:
#              S&P 500
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Concatenate all DataFrames into a single DataFrame
combine_df = pd.concat([whale_returns, algo_returns, sp500_daily_returns], axis = 1, join = "inner")
combine_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949  0.004408
# 2015-03-04  0.002416 -0.001195
# 2015-03-05  0.004323  0.014378
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance
#
# Calculate and Plot the daily returns and cumulative returns.

# %%
# Plot daily returns
combine_df.plot()

# %%
# Plot cumulative returns
cumulative_returns = (1+combine_df).cumprod()
cumulative_returns.plot()
print(cumulative_returns.tail())
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-16                   1.160965            0.786811
# 2019-04-17                   1.157602            0.781723
# 2019-04-18                   1.159278            0.782678
# 2019-04-22                   1.156280            0.776939
# 2019-04-23                   1.164568            0.779646
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-04-16                     0.862080                1.526861  1.944990
# 2019-04-17                     0.858279                1.531781  1.924954
# 2019-04-18                     0.858778                1.534716  1.923823
# 2019-04-22                     0.855652                1.533046  1.925124
# 2019-04-23                     0.861189                1.553401  1.934691
#
#               Algo 2   S&P 500
# Date
# 2019-04-16  1.267768  0.726708
# 2019-04-17  1.261140  0.725562
# 2019-04-18  1.259590  0.724829
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Risk
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %%
# Box plot to visually show risk
combine_df.boxplot(figsize =(25,12))

# %%
# Daily Standard Deviations
# Calculate the standard deviation for each portfolio. Which portfolios are riskier than the S&P 500?
combine_df.std()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P 500                        0.008587
# dtype: float64

# %%
# Determine which portfolios are riskier than the S&P 500
# Higer the standard deviation risker the asset. So, Observing the standard deviation of each individual portfolio the TIGER GLOBAL MANAGEMENT LLC
# and BERKSHIRE HATHAWAY INC are risker than industry average S&P 500.

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_var = (combine_df.var()*252)
annualized_std = np.sqrt(annualized_var)
annualized_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# S&P 500                        0.136313
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&PP 500 using a 21 day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 2. Calculate and plot a 60 day Beta for Berkshire Hathaway Inc compared to the S&&P 500

# %%
# Calculate and plot the rolling standard deviation for the S&PP 500 using a 21 day window
rolling_stat_21 = combine_df.rolling(window =21).std().plot(figsize =(25,12), title = "21 Days Moving Average")

# %%
# Correlation
correlation = combine_df.corr()
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P 500                                       0.000574            0.013549
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %%
import seaborn as sb
sb.heatmap(correlation, vmin =-1, vmax =1,)

# %%
# Calculate Beta for Berkshire Hathaway compared to the total market (S&P 500)
covariance_Berkshire_Hathaway = combine_df ['BERKSHIRE HATHAWAY INC'].cov(combine_df['S&P 500'])
covariance_Berkshire_Hathaway
# Out:
# -1.5371091324717573e-06

# %%
variance_Berkshire_Hathaway = combine_df ['BERKSHIRE HATHAWAY INC'].var()
variance_Berkshire_Hathaway
# Out:
# 0.00016689070244697312

# %%
Beta_For_Berkshire_Hathaway = covariance_Berkshire_Hathaway / variance_Berkshire_Hathaway
Beta_For_Berkshire_Hathaway.round(decimals = 5)
# Out:
# -0.00921

# %% [markdown]
# ### Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rollwing window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the `ewm` with a 21 day half-life.

# %%
# (OPTIONAL) YOUR CODE HERE
Exp_WMA_21days_halfline = combine_df.ewm(halflife=21).std().plot(figsize=(20, 10), title = "21 Days Half Line Weighted Moving Average")
Exp_WMA_21days_halfline

# %% [markdown]
# ---

# %% [markdown]
# ## Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. (After all, if you could invest in one of two portfolios, each offered the same 10% return, yet one offered lower risk, you'd take that one, right?)
#
# Calculate and plot the annualized Sharpe ratios for all portfolios to determine which portfolio has the best performance

# %%
# Annualzied Sharpe Ratios
# I ASSUME THE RISK FREE RATE IS CLOSE TO ZERO 
sharpe_ratios = combine_df.mean()*252 /(combine_df.std()*np.sqrt(252)) 
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P 500                       -0.518582
# dtype: float64

# %% [markdown]
#  plot() these sharpe ratios using a barplot.
#  On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales?

# %%
Observing the calcualted Sharpe ratios, some of our portfolios like 
SOROS FUNDMANAGEMENT LLC, BERKSHIRE HATHAWAY LLC have higher ration than the market. So, I can say
some of our portfolio have outperform the market.

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot (kind = "bar", title = "Sharpe Ratio")

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Returns
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Read the first stock
goog_historical_csv = Path("Resources/goog_historical.csv")
goog_df = pd.read_csv(goog_historical_csv, index_col = 'Trade DATE', infer_datetime_format= True, parse_dates=True)
goog_df.drop(columns =['Symbol'], axis = 1, inplace=True)
goog_df.rename(columns = {'NOCP': "GOOG"}, inplace= True)
goog_df.head(3)
# Out:
#                GOOG
# Trade DATE
# 2019-05-09  1162.38
# 2019-05-08  1166.27
# 2019-05-07  1174.10

# %%
# Read the second stock
aapl_historical_csv = Path("Resources/aapl_historical.csv")
aapl_df = pd.read_csv(aapl_historical_csv, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
aapl_df.drop(columns= ['Symbol'], axis=1, inplace= True)
aapl_df.rename(columns= {"NOCP": "AAPL"}, inplace = True)
aapl_df.head(3)
# Out:
#               AAPL
# Trade DATE
# 2019-05-09  200.72
# 2019-05-08  202.90
# 2019-05-07  202.86

# %%
# Read the third stock
cost_historical_csv = Path("Resources/cost_historical.csv")
cost_df = pd.read_csv(cost_historical_csv, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
cost_df.drop(columns= ['Symbol'], axis=1, inplace= True)
cost_df.rename(columns= {"NOCP": "COST"}, inplace = True)
cost_df.head(3)
# Out:
#               COST
# Trade DATE
# 2019-05-09  243.47
# 2019-05-08  241.34
# 2019-05-07  240.18

# %%
# Concatenate all stocks into a single DataFrame
combined_df = pd. concat([goog_df, aapl_df,cost_df], axis = 1, join = "inner")
combined_df.head(5)
# Out:
#                GOOG    AAPL    COST
# Trade DATE
# 2019-05-09  1162.38  200.72  243.47
# 2019-05-08  1166.27  202.90  241.34
# 2019-05-07  1174.10  202.86  240.18
# 2019-05-06  1189.39  208.48  244.23
# 2019-05-03  1185.40  211.75  244.62

# %%
# Reset the index
combined_df.sort_index(inplace=True)
combined_df.head()
# Out:
#                GOOG    AAPL    COST
# Trade DATE
# 2018-05-11  1098.26  188.59  195.76
# 2018-05-14  1100.20  188.15  195.88
# 2018-05-15  1079.23  186.44  195.48
# 2018-05-16  1081.77  188.18  198.71
# 2018-05-17  1078.59  186.99  199.60

# %%
# Drop Nulls
combined_df.dropna()
combined_df.head()
# Out:
#                GOOG    AAPL    COST
# Trade DATE
# 2018-05-11  1098.26  188.59  195.76
# 2018-05-14  1100.20  188.15  195.88
# 2018-05-15  1079.23  186.44  195.48
# 2018-05-16  1081.77  188.18  198.71
# 2018-05-17  1078.59  186.99  199.60

# %%
daily_returns = combined_df.pct_change()
daily_returns.head(6)
# Out:
#                 GOOG      AAPL      COST
# Trade DATE
# 2018-05-11       NaN       NaN       NaN
# 2018-05-14  0.001766 -0.002333  0.000613
# 2018-05-15 -0.019060 -0.009088 -0.002042
# 2018-05-16  0.002354  0.009333  0.016523
# 2018-05-17 -0.002940 -0.006324  0.004479
# 2018-05-18 -0.011339 -0.003637 -0.003206

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Calculate weighted portfolio returns
weights = [1/3, 1/3, 1/3]
portfolio_returns = daily_returns.dot(weights)
portfolio_returns.head(10)
# Out:
# Trade DATE
# 2018-05-11         NaN
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# 2018-05-18   -0.006061
# 2018-05-21    0.007600
# 2018-05-22   -0.004962
# 2018-05-23    0.003850
# 2018-05-24    0.000751
# dtype: float64

# %%
#Converting portfolio returns into dataframe 
portfolio1 = pd.DataFrame(portfolio_returns)
portfolio1.head()
# Out:
#                    0
# Trade DATE
# 2018-05-11       NaN
# 2018-05-14  0.000015
# 2018-05-15 -0.010064
# 2018-05-16  0.009403
# 2018-05-17 -0.001595

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
combined_portfolio = pd.concat([portfolio_returns, combine_df], axis =1, join = 'inner')
combined_portfolio.dropna(inplace =True)
combined_portfolio.sort_index()
combined_portfolio.rename(columns = {0: "My Portfolio"}, inplace = True)
combined_portfolio.head()
# Out:
#             My Portfolio  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-14      0.000015                   0.000000            0.000000
# 2018-05-15     -0.010064                  -0.000726           -0.001409
# 2018-05-16      0.009403                   0.008637            0.006244
# 2018-05-17     -0.001595                  -0.001955            0.002524
# 2018-05-18     -0.006061                  -0.004357           -0.002672
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
# 2018-05-18                    -0.012832               -0.002212  0.002557
#
#               Algo 2   S&P 500
# 2018-05-14  0.001635  0.006889
# ...

# %% [markdown]
# ## Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
# Risk
combined_portfolio.std()
annualized_variable_of_combined_portfolio = (combined_portfolio.var()*252)
annualized_std_of_combined_portfolio = np.sqrt(annualized_variable_of_combined_portfolio)
annualized_std_of_combined_portfolio
# Out:
# My Portfolio                   0.211627
# SOROS FUND MANAGEMENT LLC      0.146812
# PAULSON & CO.INC.              0.116928
# TIGER GLOBAL MANAGEMENT LLC    0.232898
# BERKSHIRE HATHAWAY INC         0.247305
# Algo 1                         0.133927
# Algo 2                         0.139499
# S&P 500                        0.152469
# dtype: float64

# %%
# Rolling
combined_portfolio.rolling(window=21).std().plot(figsize=(20,10), title = "21 Days Moving Average")

# %%
# Beta
rolling_variance = combined_portfolio['My Portfolio'].rolling(window=21).var()
rolling_covariance = combined_portfolio['My Portfolio'].rolling(window=21).cov(combined_portfolio['S&P 500'])
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20, 10), title='My Portfolio Beta')

# %%
# Annualzied Sharpe Ratios
sharpe_ratios_1 =(combined_portfolio.mean()*252- risk_free_rate)/(combined_portfolio.std()*np.sqrt(252))
sharpe_ratios_1
# Out:
# My Portfolio                   0.876152
# SOROS FUND MANAGEMENT LLC      0.380007
# PAULSON & CO.INC.              0.227577
# TIGER GLOBAL MANAGEMENT LLC   -1.066635
# BERKSHIRE HATHAWAY INC         0.103006
# Algo 1                         2.001260
# Algo 2                         0.007334
# S&P 500                       -0.427676
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios_1.plot(kind = "bar", title = "Sharpe Ratios")

# %% [markdown]
# ## Include correlation analysis to determine which stocks (if any) are correlated

# %%
# YOUR CODE HERE
correlation = combined_portfolio.corr()
correlation
# Out:
#                              My Portfolio  SOROS FUND MANAGEMENT LLC  \
# My Portfolio                     1.000000                   0.732548
# SOROS FUND MANAGEMENT LLC        0.732548                   1.000000
# PAULSON & CO.INC.                0.643828                   0.791802
# TIGER GLOBAL MANAGEMENT LLC      0.390961                   0.477844
# BERKSHIRE HATHAWAY INC           0.800558                   0.816197
# Algo 1                           0.260331                   0.336909
# Algo 2                           0.739020                   0.862583
# S&P 500                          0.005603                  -0.028256
#
#                              PAULSON & CO.INC.   TIGER GLOBAL MANAGEMENT LLC  \
# My Portfolio                           0.643828                     0.390961
# SOROS FUND MANAGEMENT LLC              0.791802                     0.477844
# PAULSON & CO.INC.                      1.000000                     0.484869
# ...

# %%
import seaborn as sb
sb.heatmap(correlation, vmin =-1, vmax = 1,)
